# %%
# %load 'gd1.py'
import numpy as np
import matplotlib.pyplot as plt

# 目標函數:y=x^2
def func(x): return np.square(x)
def dfunc(x): return 2 * x
print('---------------------------------------------------------------------------------')
#梯度下降法。給定起始點與目標函數的一階導函數，求在epochs次反覆運算中x的更新值/
#x_start: x的起始點/df: 目標函數的一階導函數/epochs: 反覆運算週期/lr: 學習率/return: x在每次反覆運算後的位置（包括起始點），長度為epochs+1
def GD(x_start, df, epochs, lr):                                 
    xs = np.zeros(epochs+1)    
    x = x_start    
    xs[0] = x    
    for i in range(epochs):         
        dx = df(x)               
        v = - dx * lr     # v表示x要改變的幅度    
        x += v        
        xs[i+1] = x    
    return xs                                                                
print('---------------------------------------------------------------------------------')
x_start=5
epochs=15
lr=0.2
x = GD(x_start, dfunc, epochs, lr) 
print (x)
print('---------------------------------------------------------------------------------')
color = 'r'    
#plt.plot(line_x, line_y, c='b')    
from numpy import arange
t = arange(-6.0, 6.0, 0.01)
plt.plot(t, func(t), c='b')
plt.plot(x, func(x), c=color, label='lr={}'.format(lr))    
plt.scatter(x, func(x), c=color, )    
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------------
# ---------------------------------------------------------------------------------
# [5.00000000e+00 3.00000000e+00 1.80000000e+00 1.08000000e+00
#  6.48000000e-01 3.88800000e-01 2.33280000e-01 1.39968000e-01
#  8.39808000e-02 5.03884800e-02 3.02330880e-02 1.81398528e-02
#  1.08839117e-02 6.53034701e-03 3.91820820e-03 2.35092492e-03]
# ---------------------------------------------------------------------------------
